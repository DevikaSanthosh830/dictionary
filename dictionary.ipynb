# %% [markdown]
# <a href="https://colab.research.google.com/github/DevikaSanthosh830/dictionary/blob/main/dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Devika={"name":"Devika", "age":24, "designation":"student"}
print(Devika["name"])
print(Devika["designation"])
print(Devika["age"])
# Out:
# Devika
# student
# 24

# %%
Devika={"birds":"peacock","birds":"parrot","birds":"crow","birds":"ostrich","birds":"hen", "food": "Biriyani","food":"friedrice","food":"chilly chicken","food":"tapiaco", "food":"mandi", "animals":"cow","animals":"buffallo","animals":"elephant","animals":"tiger","animals":"lion"}
print(Devika["birds"])
print(Devika["food"])
# Out:
# hen
# mandi

# %%
def Devika(**args):
  print(args)

# %%
def department(**kwargs):
  print(kwargs)

print(department(name="Devika",age=24,course="MSc"))
# Out:
# {'name': 'Devika', 'age': 24, 'course': 'MSc'}
# None

# %%
def Devi(name,age):
  print(name,age)

Devi(name="Devika",age=24)
# Out:
# Devika 24
